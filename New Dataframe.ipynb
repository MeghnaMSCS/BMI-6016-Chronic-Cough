# %%
# import the pandas library
import pandas as pd

# %%
diagnosis = pd.read_csv('diagnosis.csv')
diagnosis
# Out:
#                                         patient_id  \
# 0         cb210c55a430cf6b0b7de17394af7ac1ef023b11
# 1         09a69098466bb348bc9539b01f10e693779ae0d4
# 2         09a69098466bb348bc9539b01f10e693779ae0d4
# 3         1cfc222e0da79fc72ace45ebc1de9397705bc73b
# 4         1fbf8e821935996fc627573341cf02237a203ff9
# ...                                            ...
# 49254406  d407bdccdf3757a928601a2c982de465a9e85a9d
# 49254407  d407bdccdf3757a928601a2c982de465a9e85a9d
# 49254408  d407bdccdf3757a928601a2c982de465a9e85a9d
# 49254409  d407bdccdf3757a928601a2c982de465a9e85a9d
# 49254410  d407bdccdf3757a928601a2c982de465a9e85a9d
#
#                                       encounter_id code_system     code  \
# 0                                              NaN   ICD-10-CM   C90.00
# 1                                              NaN   ICD-10-CM   C81.10
# 2                                              NaN   ICD-10-CM   C81.10
# ...

# %%
patient = pd.read_csv('patient.csv')
patient.head()
# Out:
#                                  patient_id sex   race  \
# 0  c4e56388119102e00ac9df30148dcae9a55ece2b   M  White
# 1  cd92e3bb6b2ab27bd4e272d33e24ae290026d29c   M  White
# 2  7c6a487c1aeae05ce1c1ac404d00e2ae8b149ba4   F  White
# 3  68a883fa8b7c562e43ea111d86b676e3dac37bc7   F  White
# 4  6c5ceb705b0488c626cb44eb2ebf6cef697994d5   F  White
#
#                 ethnicity marital_status  year_of_birth reason_yob_missing  \
# 0                 Unknown        Unknown           1962            Present
# 1  Not Hispanic or Latino        Unknown           1975            Present
# 2  Not Hispanic or Latino        Unknown           1962            Present
# 3  Not Hispanic or Latino        Unknown           1952            Present
# 4  Not Hispanic or Latino        Unknown           1980            Present
#
#    month_year_death death_date_source_id patient_regional_location source_id
# 0               NaN                  NaN                 Northeast       EHR
# ...

# %%
new_df = pd.merge(patient, diagnosis, how='inner', left_on = 'patient_id', right_on = 'patient_id')
new_df
# Out:
#                                         patient_id sex   race  \
# 0         c4e56388119102e00ac9df30148dcae9a55ece2b   M  White
# 1         c4e56388119102e00ac9df30148dcae9a55ece2b   M  White
# 2         c4e56388119102e00ac9df30148dcae9a55ece2b   M  White
# 3         c4e56388119102e00ac9df30148dcae9a55ece2b   M  White
# 4         c4e56388119102e00ac9df30148dcae9a55ece2b   M  White
# ...                                            ...  ..    ...
# 49254406  9d70de10ef1ed0c2aed9a1c4b28d63d799cf93bd   F  White
# 49254407  9d70de10ef1ed0c2aed9a1c4b28d63d799cf93bd   F  White
# 49254408  9d70de10ef1ed0c2aed9a1c4b28d63d799cf93bd   F  White
# 49254409  9d70de10ef1ed0c2aed9a1c4b28d63d799cf93bd   F  White
# 49254410  9d70de10ef1ed0c2aed9a1c4b28d63d799cf93bd   F  White
#
#                        ethnicity marital_status  year_of_birth  \
# 0                        Unknown        Unknown           1962
# 1                        Unknown        Unknown           1962
# ...
